# %% [markdown]
# ### Neural machine translation

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %% [markdown]
# ### Download and prepare the dataset

# %% [markdown]
# We'll use a language dataset provided by http://www.manythings.org/anki/

# %%
# Download the file
path_to_file = "./data/translation/rus.txt"

# %%
def preprocess_sentence(w):
    w = w.lower().strip()
    
    # creating a space between a word and the punctuation following it
    # eg: "he is a boy." => "he is a boy ."
    # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
    w = re.sub(r"([?.!,])", r" \1 ", w)
    w = re.sub(r'[" "]+', " ", w)

    # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
    w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

    w = w.strip()

    # adding a start and an end token to the sentence
    # so that the model know when to start and stop predicting.
    w = '<start> ' + w + ' <end>'
    return w

# %%
preprocess_sentence("I can't go.")
# Out:
# "<start> i can't go . <end>"

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENG, RUS]
def create_dataset(path, num_examples):
    lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

    word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

    return zip(*word_pairs)

# %%
en, ru = create_dataset(path_to_file, None)
print(en[0])
print(ru[0])
# Out:
# <start> go . <end>
# <start> марш ! <end>

# %%
en[10:20]
# Out:
# ('<start> run ! <end>',
#  '<start> run . <end>',
#  '<start> run . <end>',
#  '<start> who ? <end>',
#  '<start> wow ! <end>',
#  '<start> wow ! <end>',
#  '<start> wow ! <end>',
#  '<start> wow ! <end>',
#  '<start> wow ! <end>',
#  '<start> wow ! <end>')

# %%
ru[10:20]
# Out:
# ('<start> бегите ! <end>',
#  '<start> беги ! <end>',
#  '<start> бегите ! <end>',
#  '<start> кто ? <end>',
#  '<start> вот это да ! <end>',
#  '<start> круто ! <end>',
#  '<start> здорово ! <end>',
#  '<start> ух ты ! <end>',
#  '<start> ого ! <end>',
#  '<start> вах ! <end>')

# %%
def tokenize(lang):
    lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
    lang_tokenizer.fit_on_texts(lang)

    tensor = lang_tokenizer.texts_to_sequences(lang)

    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

    return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
    # creating cleaned input, output pairs
    targ_lang, inp_lang = create_dataset(path, num_examples)

    input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
    target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

    return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
tokenize(ru[10:20])
# Out:
# (array([[ 1,  4,  3,  2,  0,  0],
#         [ 1,  5,  3,  2,  0,  0],
#         [ 1,  4,  3,  2,  0,  0],
#         [ 1,  6,  7,  2,  0,  0],
#         [ 1,  8,  9, 10,  3,  2],
#         [ 1, 11,  3,  2,  0,  0],
#         [ 1, 12,  3,  2,  0,  0],
#         [ 1, 13, 14,  3,  2,  0],
#         [ 1, 15,  3,  2,  0,  0],
#         [ 1, 16,  3,  2,  0,  0]], dtype=int32),
#  <keras_preprocessing.text.Tokenizer at 0x7fe03555ea58>)

# %% [markdown]
# ### Limit the size of the dataset to experiment faster (optional)

# %%
len(en), len(ru)
# Out:
# (431097, 431097)

# %%
# Try experimenting with the size of that dataset
num_examples = 100000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
max_length_targ, max_length_inp
# Out:
# (11, 15)

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 80000 80000 20000 20000

# %%
def convert(lang, tensor):
    for t in tensor:
        if t!=0:
            print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 122 ----> дай
# 138 ----> им
# 571 ----> войти
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 89 ----> let
# 99 ----> them
# 66 ----> come
# 35 ----> in
# 3 ----> .
# 2 ----> <end>

# %% [markdown]
# ### Create a tf.data dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 300
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 15]), TensorShape([64, 11]))

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.enc_units,
                                       return_sequences=False,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
    
    
    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        return state

    
    def initialize_hidden_state(self):
        return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_hidden = encoder(example_input_batch, sample_hidden)
# print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.dec_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.fc = tf.keras.layers.Dense(vocab_size)


    
    def call(self, x, hidden):
        # enc_output shape == (batch_size, max_length, hidden_size)
        
        # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)
        
        # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
        
        # passing the concatenated vector to the GRU
        output, state = self.gru(x, initial_state=hidden)
        
        # output shape == (batch_size * 1, hidden_size)
        output = tf.reshape(output, (-1, output.shape[2]))
        
        # output shape == (batch_size, vocab)
        x = self.fc(output)
        
        return x, state

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_sample_x, decoder_sample_h = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                             sample_hidden)

# %%
decoder_sample_x.shape
# Out:
# TensorShape([64, 7260])

# %%
decoder_sample_h.shape
# Out:
# TensorShape([64, 1024])

# %% [markdown]
# ### Define the optimizer and the loss function

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %% [markdown]
# ### Checkpoints (Object-based saving)

# %%
checkpoint_dir = './training_nmt_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0

    with tf.GradientTape() as tape:
        enc_hidden = encoder(inp, enc_hidden)
        
        dec_hidden = enc_hidden
        
        dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)
        
        # Teacher forcing - feeding the target as the next input
        for t in range(1, targ.shape[1]):
            # passing enc_output to the decoder
            predictions, dec_hidden = decoder(dec_input, dec_hidden)
            
            loss += loss_function(targ[:, t], predictions)
            
            # using teacher forcing
            dec_input = tf.expand_dims(targ[:, t], 1)

    batch_loss = (loss / int(targ.shape[1]))

    variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, variables)

    optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

# %%
# %%time

EPOCHS = 50

for epoch in range(EPOCHS):
    start = time.time()
    
    enc_hidden = encoder.initialize_hidden_state()
    total_loss = 0
    
    for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
        batch_loss = train_step(inp, targ, enc_hidden)
        total_loss += batch_loss

        if batch % 100 == 0:
            print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
    # saving (checkpoint) the model every 2 epochs
    if (epoch + 1) % 2 == 0:
        checkpoint.save(file_prefix = checkpoint_prefix)

    print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.6597
# Epoch 1 Batch 100 Loss 1.9972
# Epoch 1 Batch 200 Loss 1.7233
# Epoch 1 Batch 300 Loss 1.7129
# Epoch 1 Batch 400 Loss 1.6030
# Epoch 1 Batch 500 Loss 1.5352
# Epoch 1 Batch 600 Loss 1.4080
# Epoch 1 Batch 700 Loss 1.3399
# Epoch 1 Batch 800 Loss 1.2970
# Epoch 1 Batch 900 Loss 1.1240
# Epoch 1 Batch 1000 Loss 1.1781
# Epoch 1 Batch 1100 Loss 1.0053
# Epoch 1 Batch 1200 Loss 1.1517
# Epoch 1 Loss 1.4725
# Time taken for 1 epoch 798.4947366714478 sec
#
# Epoch 2 Batch 0 Loss 0.9337
# Epoch 2 Batch 100 Loss 0.8786
# Epoch 2 Batch 200 Loss 0.8134
# Epoch 2 Batch 300 Loss 0.8870
# Epoch 2 Batch 400 Loss 0.9022
# Epoch 2 Batch 500 Loss 0.7981
# Epoch 2 Batch 600 Loss 0.7729
# Epoch 2 Batch 700 Loss 0.7666
# Epoch 2 Batch 800 Loss 0.6648
# Epoch 2 Batch 900 Loss 0.7020
# Epoch 2 Batch 1000 Loss 0.7426
# Epoch 2 Batch 1100 Loss 0.6918
# Epoch 2 Batch 1200 Loss 0.6418
# Epoch 2 Loss 0.7800
# Time taken for 1 epoch 770.3030886650085 sec
#
# Epoch 3 Batch 0 Loss 0.4400
# Epoch 3 Batch 100 Loss 0.4200
# Epoch 3 Batch 200 Loss 0.4415
# Epoch 3 Batch 300 Loss 0.3833
# Epoch 3 Batch 400 Loss 0.5035
# Epoch 3 Batch 500 Loss 0.4524
# Epoch 3 Batch 600 Loss 0.5158
# Epoch 3 Batch 700 Loss 0.4321
# Epoch 3 Batch 800 Loss 0.3388
# Epoch 3 Batch 900 Loss 0.3573
# Epoch 3 Batch 1000 Loss 0.4316
# Epoch 3 Batch 1100 Loss 0.3760
# Epoch 3 Batch 1200 Loss 0.4314
# Epoch 3 Loss 0.4416
# Time taken for 1 epoch 788.3185830116272 sec
#
# Epoch 4 Batch 0 Loss 0.2226
# Epoch 4 Batch 100 Loss 0.2743
# Epoch 4 Batch 200 Loss 0.2608
# Epoch 4 Batch 300 Loss 0.2400
# Epoch 4 Batch 400 Loss 0.3112
# Epoch 4 Batch 500 Loss 0.2071
# Epoch 4 Batch 600 Loss 0.2846
# Epoch 4 Batch 700 Loss 0.2797
# Epoch 4 Batch 800 Loss 0.2381
# Epoch 4 Batch 900 Loss 0.2586
# Epoch 4 Batch 1000 Loss 0.2999
# Epoch 4 Batch 1100 Loss 0.2217
# Epoch 4 Batch 1200 Loss 0.3004
# Epoch 4 Loss 0.2673
# Time taken for 1 epoch 780.5089557170868 sec
#
# Epoch 5 Batch 0 Loss 0.1643
# Epoch 5 Batch 100 Loss 0.2041
# Epoch 5 Batch 200 Loss 0.1507
# Epoch 5 Batch 300 Loss 0.1793
# Epoch 5 Batch 400 Loss 0.1898
# Epoch 5 Batch 500 Loss 0.2311
# Epoch 5 Batch 600 Loss 0.1731
# Epoch 5 Batch 700 Loss 0.2148
# Epoch 5 Batch 800 Loss 0.1932
# Epoch 5 Batch 900 Loss 0.2057
# Epoch 5 Batch 1000 Loss 0.2029
# Epoch 5 Batch 1100 Loss 0.1873
# Epoch 5 Batch 1200 Loss 0.1817
# Epoch 5 Loss 0.1791
# Time taken for 1 epoch 790.9423544406891 sec
#
# Epoch 6 Batch 0 Loss 0.1505
# Epoch 6 Batch 100 Loss 0.0975
# Epoch 6 Batch 200 Loss 0.1293
# Epoch 6 Batch 300 Loss 0.1145
# Epoch 6 Batch 400 Loss 0.1252
# Epoch 6 Batch 500 Loss 0.1332
# Epoch 6 Batch 600 Loss 0.1211
# Epoch 6 Batch 700 Loss 0.1504
# Epoch 6 Batch 800 Loss 0.1455
# Epoch 6 Batch 900 Loss 0.1653
# Epoch 6 Batch 1000 Loss 0.1099
# Epoch 6 Batch 1100 Loss 0.1217
# Epoch 6 Batch 1200 Loss 0.1369
# Epoch 6 Loss 0.1344
# Time taken for 1 epoch 777.6717519760132 sec
#
# Epoch 7 Batch 0 Loss 0.0854
# Epoch 7 Batch 100 Loss 0.0664
# Epoch 7 Batch 200 Loss 0.0881
# Epoch 7 Batch 300 Loss 0.1019
# Epoch 7 Batch 400 Loss 0.1048
# Epoch 7 Batch 500 Loss 0.1151
# Epoch 7 Batch 600 Loss 0.1267
# Epoch 7 Batch 700 Loss 0.1368
# Epoch 7 Batch 800 Loss 0.1114
# Epoch 7 Batch 900 Loss 0.0961
# Epoch 7 Batch 1000 Loss 0.1123
# Epoch 7 Batch 1100 Loss 0.1334
# Epoch 7 Batch 1200 Loss 0.1101
# Epoch 7 Loss 0.1106
# Time taken for 1 epoch 777.1551578044891 sec
#
# Epoch 8 Batch 0 Loss 0.1334
# Epoch 8 Batch 100 Loss 0.0881
# Epoch 8 Batch 200 Loss 0.0719
# Epoch 8 Batch 300 Loss 0.0849
# Epoch 8 Batch 400 Loss 0.1044
# Epoch 8 Batch 500 Loss 0.1073
# Epoch 8 Batch 600 Loss 0.1020
# Epoch 8 Batch 700 Loss 0.0810
# Epoch 8 Batch 800 Loss 0.1068
# Epoch 8 Batch 900 Loss 0.1129
# Epoch 8 Batch 1000 Loss 0.0885
# Epoch 8 Batch 1100 Loss 0.1040
# Epoch 8 Batch 1200 Loss 0.1146
# Epoch 8 Loss 0.0973
# Time taken for 1 epoch 775.207466840744 sec
#
# Epoch 9 Batch 0 Loss 0.0976
# Epoch 9 Batch 100 Loss 0.0888
# Epoch 9 Batch 200 Loss 0.0729
# Epoch 9 Batch 300 Loss 0.0797
# Epoch 9 Batch 400 Loss 0.0768
# Epoch 9 Batch 500 Loss 0.1048
# Epoch 9 Batch 600 Loss 0.0895
# Epoch 9 Batch 700 Loss 0.0923
# Epoch 9 Batch 800 Loss 0.0890
# Epoch 9 Batch 900 Loss 0.0826
# Epoch 9 Batch 1000 Loss 0.1009
# Epoch 9 Batch 1100 Loss 0.1349
# Epoch 9 Batch 1200 Loss 0.1228
# Epoch 9 Loss 0.0895
# Time taken for 1 epoch 780.1013376712799 sec
#
# Epoch 10 Batch 0 Loss 0.1096
# Epoch 10 Batch 100 Loss 0.0433
# Epoch 10 Batch 200 Loss 0.0618
# Epoch 10 Batch 300 Loss 0.1299
# Epoch 10 Batch 400 Loss 0.0498
# Epoch 10 Batch 500 Loss 0.1000
# Epoch 10 Batch 600 Loss 0.0724
# Epoch 10 Batch 700 Loss 0.1313
# Epoch 10 Batch 800 Loss 0.0651
# Epoch 10 Batch 900 Loss 0.0848
# Epoch 10 Batch 1000 Loss 0.0958
# Epoch 10 Batch 1100 Loss 0.1014
# Epoch 10 Batch 1200 Loss 0.0719
# Epoch 10 Loss 0.0840
# Time taken for 1 epoch 786.0730273723602 sec
#
# Epoch 11 Batch 0 Loss 0.1148
# Epoch 11 Batch 100 Loss 0.0619
# Epoch 11 Batch 200 Loss 0.0777
# Epoch 11 Batch 300 Loss 0.0580
# Epoch 11 Batch 400 Loss 0.0792
# Epoch 11 Batch 500 Loss 0.0905
# Epoch 11 Batch 600 Loss 0.0788
# Epoch 11 Batch 700 Loss 0.0710
# Epoch 11 Batch 800 Loss 0.0765
# Epoch 11 Batch 900 Loss 0.0962
# Epoch 11 Batch 1000 Loss 0.0760
# Epoch 11 Batch 1100 Loss 0.0738
# Epoch 11 Batch 1200 Loss 0.0992
# Epoch 11 Loss 0.0798
# Time taken for 1 epoch 773.923166513443 sec
#
# Epoch 12 Batch 0 Loss 0.0503
# Epoch 12 Batch 100 Loss 0.0559
# Epoch 12 Batch 200 Loss 0.0671
# Epoch 12 Batch 300 Loss 0.0376
# Epoch 12 Batch 400 Loss 0.0481
# Epoch 12 Batch 500 Loss 0.0608
# Epoch 12 Batch 600 Loss 0.0764
# Epoch 12 Batch 700 Loss 0.1065
# Epoch 12 Batch 800 Loss 0.0662
# Epoch 12 Batch 900 Loss 0.0567
# Epoch 12 Batch 1000 Loss 0.1054
# Epoch 12 Batch 1100 Loss 0.0873
# Epoch 12 Batch 1200 Loss 0.0736
# Epoch 12 Loss 0.0761
# Time taken for 1 epoch 781.2444989681244 sec
#
# Epoch 13 Batch 0 Loss 0.0769
# Epoch 13 Batch 100 Loss 0.0441
# Epoch 13 Batch 200 Loss 0.0392
# Epoch 13 Batch 300 Loss 0.0633
# Epoch 13 Batch 400 Loss 0.0571
# Epoch 13 Batch 500 Loss 0.0740
# Epoch 13 Batch 600 Loss 0.0378
# Epoch 13 Batch 700 Loss 0.0483
# Epoch 13 Batch 800 Loss 0.0751
# Epoch 13 Batch 900 Loss 0.0788
# Epoch 13 Batch 1000 Loss 0.0305
# Epoch 13 Batch 1100 Loss 0.0763
# Epoch 13 Batch 1200 Loss 0.0877
# Epoch 13 Loss 0.0733
# Time taken for 1 epoch 768.1168217658997 sec
#
# Epoch 14 Batch 0 Loss 0.0576
# Epoch 14 Batch 100 Loss 0.0644
# Epoch 14 Batch 200 Loss 0.0631
# Epoch 14 Batch 300 Loss 0.0452
# Epoch 14 Batch 400 Loss 0.0971
# Epoch 14 Batch 500 Loss 0.0571
# Epoch 14 Batch 600 Loss 0.0609
# Epoch 14 Batch 700 Loss 0.0914
# Epoch 14 Batch 800 Loss 0.0743
# Epoch 14 Batch 900 Loss 0.0691
# Epoch 14 Batch 1000 Loss 0.1123
# Epoch 14 Batch 1100 Loss 0.0811
# Epoch 14 Batch 1200 Loss 0.0779
# Epoch 14 Loss 0.0728
# Time taken for 1 epoch 782.6631500720978 sec
#
# Epoch 15 Batch 0 Loss 0.0346
# Epoch 15 Batch 100 Loss 0.0489
# Epoch 15 Batch 200 Loss 0.0456
# Epoch 15 Batch 300 Loss 0.0592
# Epoch 15 Batch 400 Loss 0.0378
# Epoch 15 Batch 500 Loss 0.0662
# Epoch 15 Batch 600 Loss 0.0713
# Epoch 15 Batch 700 Loss 0.0946
# Epoch 15 Batch 800 Loss 0.0651
# Epoch 15 Batch 900 Loss 0.0943
# Epoch 15 Batch 1000 Loss 0.0580
# Epoch 15 Batch 1100 Loss 0.0746
# Epoch 15 Batch 1200 Loss 0.1225
# Epoch 15 Loss 0.0694
# Time taken for 1 epoch 785.1079480648041 sec
#
# Epoch 16 Batch 0 Loss 0.0356
# Epoch 16 Batch 100 Loss 0.0589
# Epoch 16 Batch 200 Loss 0.0537
# Epoch 16 Batch 300 Loss 0.0329
# Epoch 16 Batch 400 Loss 0.0759
# Epoch 16 Batch 500 Loss 0.0736
# Epoch 16 Batch 600 Loss 0.0373
# Epoch 16 Batch 700 Loss 0.0746
# Epoch 16 Batch 800 Loss 0.0985
# Epoch 16 Batch 900 Loss 0.0837
# Epoch 16 Batch 1000 Loss 0.0795
# Epoch 16 Batch 1100 Loss 0.0604
# Epoch 16 Batch 1200 Loss 0.0807
# Epoch 16 Loss 0.0692
# Time taken for 1 epoch 792.8959112167358 sec
#
# Epoch 17 Batch 0 Loss 0.0572
# Epoch 17 Batch 100 Loss 0.0171
# Epoch 17 Batch 200 Loss 0.0598
# Epoch 17 Batch 300 Loss 0.0555
# Epoch 17 Batch 400 Loss 0.0537
# Epoch 17 Batch 500 Loss 0.0642
# Epoch 17 Batch 600 Loss 0.0514
# Epoch 17 Batch 700 Loss 0.0974
# Epoch 17 Batch 800 Loss 0.0534
# Epoch 17 Batch 900 Loss 0.0790
# Epoch 17 Batch 1000 Loss 0.0650
# Epoch 17 Batch 1100 Loss 0.0989
# Epoch 17 Batch 1200 Loss 0.0743
# Epoch 17 Loss 0.0670
# Time taken for 1 epoch 785.9260907173157 sec
#
# Epoch 18 Batch 0 Loss 0.0685
# Epoch 18 Batch 100 Loss 0.0721
# Epoch 18 Batch 200 Loss 0.0737
# Epoch 18 Batch 300 Loss 0.0929
# Epoch 18 Batch 400 Loss 0.0615
# Epoch 18 Batch 500 Loss 0.0455
# Epoch 18 Batch 600 Loss 0.0728
# Epoch 18 Batch 700 Loss 0.0435
# Epoch 18 Batch 800 Loss 0.0683
# Epoch 18 Batch 900 Loss 0.0800
# Epoch 18 Batch 1000 Loss 0.0949
# Epoch 18 Batch 1100 Loss 0.0425
# Epoch 18 Batch 1200 Loss 0.0814
# Epoch 18 Loss 0.0651
# Time taken for 1 epoch 771.4019482135773 sec
#
# Epoch 19 Batch 0 Loss 0.0518
# Epoch 19 Batch 100 Loss 0.0626
# Epoch 19 Batch 200 Loss 0.0624
# Epoch 19 Batch 300 Loss 0.0486
# Epoch 19 Batch 400 Loss 0.0706
# Epoch 19 Batch 500 Loss 0.0684
# Epoch 19 Batch 600 Loss 0.0801
# Epoch 19 Batch 700 Loss 0.0649
# Epoch 19 Batch 800 Loss 0.0729
# Epoch 19 Batch 900 Loss 0.0485
# Epoch 19 Batch 1000 Loss 0.0684
# Epoch 19 Batch 1100 Loss 0.0611
# Epoch 19 Batch 1200 Loss 0.1043
# Epoch 19 Loss 0.0645
# Time taken for 1 epoch 786.1595189571381 sec
#
# Epoch 20 Batch 0 Loss 0.0627
# Epoch 20 Batch 100 Loss 0.0773
# Epoch 20 Batch 200 Loss 0.0605
# Epoch 20 Batch 300 Loss 0.0609
# Epoch 20 Batch 400 Loss 0.0534
# Epoch 20 Batch 500 Loss 0.0302
# Epoch 20 Batch 600 Loss 0.0738
# Epoch 20 Batch 700 Loss 0.0260
# Epoch 20 Batch 800 Loss 0.0669
# Epoch 20 Batch 900 Loss 0.0723
# Epoch 20 Batch 1000 Loss 0.0549
# Epoch 20 Batch 1100 Loss 0.0810
# Epoch 20 Batch 1200 Loss 0.0839
# Epoch 20 Loss 0.0637
# Time taken for 1 epoch 787.3731484413147 sec
#
# Epoch 21 Batch 0 Loss 0.0665
# Epoch 21 Batch 100 Loss 0.0857
# Epoch 21 Batch 200 Loss 0.0255
# Epoch 21 Batch 300 Loss 0.0572
# Epoch 21 Batch 400 Loss 0.0578
# Epoch 21 Batch 500 Loss 0.0675
# Epoch 21 Batch 600 Loss 0.0632
# Epoch 21 Batch 700 Loss 0.0702
# Epoch 21 Batch 800 Loss 0.0427
# Epoch 21 Batch 900 Loss 0.0697
# Epoch 21 Batch 1000 Loss 0.0952
# Epoch 21 Batch 1100 Loss 0.0639
# Epoch 21 Batch 1200 Loss 0.0355
# Epoch 21 Loss 0.0625
# Time taken for 1 epoch 767.2119240760803 sec
#
# Epoch 22 Batch 0 Loss 0.0370
# Epoch 22 Batch 100 Loss 0.0583
# Epoch 22 Batch 200 Loss 0.0629
# Epoch 22 Batch 300 Loss 0.0371
# Epoch 22 Batch 400 Loss 0.0674
# Epoch 22 Batch 500 Loss 0.0789
# Epoch 22 Batch 600 Loss 0.0791
# Epoch 22 Batch 700 Loss 0.0390
# Epoch 22 Batch 800 Loss 0.0424
# Epoch 22 Batch 900 Loss 0.0490
# Epoch 22 Batch 1000 Loss 0.0818
# Epoch 22 Batch 1100 Loss 0.0632
# Epoch 22 Batch 1200 Loss 0.0587
# Epoch 22 Loss 0.0613
# Time taken for 1 epoch 774.9462366104126 sec
#
# Epoch 23 Batch 0 Loss 0.0486
# Epoch 23 Batch 100 Loss 0.0256
# Epoch 23 Batch 200 Loss 0.0639
# Epoch 23 Batch 300 Loss 0.0443
# Epoch 23 Batch 400 Loss 0.0392
# Epoch 23 Batch 500 Loss 0.0453
# Epoch 23 Batch 600 Loss 0.0227
# Epoch 23 Batch 700 Loss 0.0697
# Epoch 23 Batch 800 Loss 0.0424
# Epoch 23 Batch 900 Loss 0.0660
# Epoch 23 Batch 1000 Loss 0.0361
# Epoch 23 Batch 1100 Loss 0.0430
# Epoch 23 Batch 1200 Loss 0.0705
# Epoch 23 Loss 0.0603
# Time taken for 1 epoch 772.627819776535 sec
#
# Epoch 24 Batch 0 Loss 0.0431
# Epoch 24 Batch 100 Loss 0.0421
# Epoch 24 Batch 200 Loss 0.0499
# Epoch 24 Batch 300 Loss 0.0322
# Epoch 24 Batch 400 Loss 0.0538
# Epoch 24 Batch 500 Loss 0.0575
# Epoch 24 Batch 600 Loss 0.0487
# Epoch 24 Batch 700 Loss 0.0285
# Epoch 24 Batch 800 Loss 0.0358
# Epoch 24 Batch 900 Loss 0.0598
# Epoch 24 Batch 1000 Loss 0.0825
# Epoch 24 Batch 1100 Loss 0.1221
# Epoch 24 Batch 1200 Loss 0.0550
# Epoch 24 Loss 0.0601
# Time taken for 1 epoch 786.734050989151 sec
#
# Epoch 25 Batch 0 Loss 0.0561
# Epoch 25 Batch 100 Loss 0.0515
# Epoch 25 Batch 200 Loss 0.0621
# Epoch 25 Batch 300 Loss 0.0295
# Epoch 25 Batch 400 Loss 0.0680
# Epoch 25 Batch 500 Loss 0.0225
# Epoch 25 Batch 600 Loss 0.0207
# Epoch 25 Batch 700 Loss 0.0421
# Epoch 25 Batch 800 Loss 0.0313
# Epoch 25 Batch 900 Loss 0.0490
# Epoch 25 Batch 1000 Loss 0.0661
# Epoch 25 Batch 1100 Loss 0.0462
# Epoch 25 Batch 1200 Loss 0.0761
# Epoch 25 Loss 0.0593
# Time taken for 1 epoch 780.2488992214203 sec
#
# Epoch 26 Batch 0 Loss 0.0349
# Epoch 26 Batch 100 Loss 0.0296
# Epoch 26 Batch 200 Loss 0.0518
# Epoch 26 Batch 300 Loss 0.0286
# Epoch 26 Batch 400 Loss 0.0421
# Epoch 26 Batch 500 Loss 0.0670
# Epoch 26 Batch 600 Loss 0.0786
# Epoch 26 Batch 700 Loss 0.0465
# Epoch 26 Batch 800 Loss 0.0693
# Epoch 26 Batch 900 Loss 0.0440
# Epoch 26 Batch 1000 Loss 0.0864
# Epoch 26 Batch 1100 Loss 0.0659
# Epoch 26 Batch 1200 Loss 0.0527
# Epoch 26 Loss 0.0577
# Time taken for 1 epoch 768.3086466789246 sec
#
# Epoch 27 Batch 0 Loss 0.0343
# Epoch 27 Batch 100 Loss 0.0424
# Epoch 27 Batch 200 Loss 0.0791
# Epoch 27 Batch 300 Loss 0.0630
# Epoch 27 Batch 400 Loss 0.0852
# Epoch 27 Batch 500 Loss 0.0862
# Epoch 27 Batch 600 Loss 0.0369
# Epoch 27 Batch 700 Loss 0.0328
# Epoch 27 Batch 800 Loss 0.0660
# Epoch 27 Batch 900 Loss 0.0302
# Epoch 27 Batch 1000 Loss 0.0307
# Epoch 27 Batch 1100 Loss 0.0875
# Epoch 27 Batch 1200 Loss 0.0443
# Epoch 27 Loss 0.0571
# Time taken for 1 epoch 788.5534949302673 sec
#
# Epoch 28 Batch 0 Loss 0.0409
# Epoch 28 Batch 100 Loss 0.0577
# Epoch 28 Batch 200 Loss 0.0520
# Epoch 28 Batch 300 Loss 0.0457
# Epoch 28 Batch 400 Loss 0.0576
# Epoch 28 Batch 500 Loss 0.0641
# Epoch 28 Batch 600 Loss 0.0671
# Epoch 28 Batch 700 Loss 0.0502
# Epoch 28 Batch 800 Loss 0.0634
# Epoch 28 Batch 900 Loss 0.0872
# Epoch 28 Batch 1000 Loss 0.0522
# Epoch 28 Batch 1100 Loss 0.0372
# Epoch 28 Batch 1200 Loss 0.0859
# Epoch 28 Loss 0.0570
# Time taken for 1 epoch 776.6003370285034 sec
#
# Epoch 29 Batch 0 Loss 0.0338
# Epoch 29 Batch 100 Loss 0.0416
# Epoch 29 Batch 200 Loss 0.0806
# Epoch 29 Batch 300 Loss 0.0678
# Epoch 29 Batch 400 Loss 0.0429
# Epoch 29 Batch 500 Loss 0.0540
# Epoch 29 Batch 600 Loss 0.0577
# Epoch 29 Batch 700 Loss 0.0761
# Epoch 29 Batch 800 Loss 0.0517
# Epoch 29 Batch 900 Loss 0.0394
# Epoch 29 Batch 1000 Loss 0.0426
# Epoch 29 Batch 1100 Loss 0.0565
# Epoch 29 Batch 1200 Loss 0.0997
# Epoch 29 Loss 0.0559
# Time taken for 1 epoch 774.6908633708954 sec
#
# Epoch 30 Batch 0 Loss 0.0498
# Epoch 30 Batch 100 Loss 0.0278
# Epoch 30 Batch 200 Loss 0.0987
# Epoch 30 Batch 300 Loss 0.0352
# Epoch 30 Batch 400 Loss 0.0405
# Epoch 30 Batch 500 Loss 0.0438
# Epoch 30 Batch 600 Loss 0.0760
# Epoch 30 Batch 700 Loss 0.0581
# Epoch 30 Batch 800 Loss 0.0539
# Epoch 30 Batch 900 Loss 0.0454
# Epoch 30 Batch 1000 Loss 0.1046
# Epoch 30 Batch 1100 Loss 0.0584
# Epoch 30 Batch 1200 Loss 0.0663
# Epoch 30 Loss 0.0556
# Time taken for 1 epoch 781.023998260498 sec
#
# Epoch 31 Batch 0 Loss 0.0379
# Epoch 31 Batch 100 Loss 0.0327
# Epoch 31 Batch 200 Loss 0.0444
# Epoch 31 Batch 300 Loss 0.0646
# Epoch 31 Batch 400 Loss 0.0448
# Epoch 31 Batch 500 Loss 0.0812
# Epoch 31 Batch 600 Loss 0.0811
# Epoch 31 Batch 700 Loss 0.0786
# Epoch 31 Batch 800 Loss 0.0466
# Epoch 31 Batch 900 Loss 0.0582
# Epoch 31 Batch 1000 Loss 0.0698
# Epoch 31 Batch 1100 Loss 0.1346
# Epoch 31 Batch 1200 Loss 0.0490
# Epoch 31 Loss 0.0549
# Time taken for 1 epoch 780.5652937889099 sec
#
# Epoch 32 Batch 0 Loss 0.1105
# Epoch 32 Batch 100 Loss 0.0669
# Epoch 32 Batch 200 Loss 0.0452
# Epoch 32 Batch 300 Loss 0.0522
# Epoch 32 Batch 400 Loss 0.0212
# Epoch 32 Batch 500 Loss 0.0636
# Epoch 32 Batch 600 Loss 0.0557
# Epoch 32 Batch 700 Loss 0.0569
# Epoch 32 Batch 800 Loss 0.0827
# Epoch 32 Batch 900 Loss 0.0503
# Epoch 32 Batch 1000 Loss 0.0477
# Epoch 32 Batch 1100 Loss 0.0611
# Epoch 32 Batch 1200 Loss 0.1193
# Epoch 32 Loss 0.0544
# Time taken for 1 epoch 791.6402139663696 sec
#
# Epoch 33 Batch 0 Loss 0.0294
# Epoch 33 Batch 100 Loss 0.0326
# Epoch 33 Batch 200 Loss 0.0630
# Epoch 33 Batch 300 Loss 0.0469
# Epoch 33 Batch 400 Loss 0.0820
# Epoch 33 Batch 500 Loss 0.0390
# Epoch 33 Batch 600 Loss 0.0368
# Epoch 33 Batch 700 Loss 0.0679
# Epoch 33 Batch 800 Loss 0.0692
# Epoch 33 Batch 900 Loss 0.0361
# Epoch 33 Batch 1000 Loss 0.0454
# Epoch 33 Batch 1100 Loss 0.0964
# Epoch 33 Batch 1200 Loss 0.0684
# Epoch 33 Loss 0.0537
# Time taken for 1 epoch 773.3307814598083 sec
#
# Epoch 34 Batch 0 Loss 0.0421
# Epoch 34 Batch 100 Loss 0.0612
# Epoch 34 Batch 200 Loss 0.0601
# Epoch 34 Batch 300 Loss 0.0375
# Epoch 34 Batch 400 Loss 0.0849
# Epoch 34 Batch 500 Loss 0.0418
# Epoch 34 Batch 600 Loss 0.0264
# Epoch 34 Batch 700 Loss 0.0715
# Epoch 34 Batch 800 Loss 0.0277
# Epoch 34 Batch 900 Loss 0.0689
# Epoch 34 Batch 1000 Loss 0.0627
# Epoch 34 Batch 1100 Loss 0.0410
# Epoch 34 Batch 1200 Loss 0.0587
# Epoch 34 Loss 0.0532
# Time taken for 1 epoch 794.4943823814392 sec
#
# Epoch 35 Batch 0 Loss 0.0252
# Epoch 35 Batch 100 Loss 0.0584
# Epoch 35 Batch 200 Loss 0.0263
# Epoch 35 Batch 300 Loss 0.0422
# Epoch 35 Batch 400 Loss 0.0393
# Epoch 35 Batch 500 Loss 0.0415
# Epoch 35 Batch 600 Loss 0.0803
# Epoch 35 Batch 700 Loss 0.0485
# Epoch 35 Batch 800 Loss 0.0634
# Epoch 35 Batch 900 Loss 0.0622
# Epoch 35 Batch 1000 Loss 0.0541
# Epoch 35 Batch 1100 Loss 0.0638
# Epoch 35 Batch 1200 Loss 0.0668
# Epoch 35 Loss 0.0531
# Time taken for 1 epoch 782.8898627758026 sec
#
# Epoch 36 Batch 0 Loss 0.0256
# Epoch 36 Batch 100 Loss 0.0345
# Epoch 36 Batch 200 Loss 0.0496
# Epoch 36 Batch 300 Loss 0.0408
# Epoch 36 Batch 400 Loss 0.0418
# Epoch 36 Batch 500 Loss 0.0671
# Epoch 36 Batch 600 Loss 0.0605
# Epoch 36 Batch 700 Loss 0.0534
# Epoch 36 Batch 800 Loss 0.0619
# Epoch 36 Batch 900 Loss 0.0418
# Epoch 36 Batch 1000 Loss 0.0831
# Epoch 36 Batch 1100 Loss 0.0898
# Epoch 36 Batch 1200 Loss 0.0827
# Epoch 36 Loss 0.0522
# Time taken for 1 epoch 776.7171592712402 sec
#
# Epoch 37 Batch 0 Loss 0.0449
# Epoch 37 Batch 100 Loss 0.0372
# Epoch 37 Batch 200 Loss 0.0137
# Epoch 37 Batch 300 Loss 0.0421
# Epoch 37 Batch 400 Loss 0.0348
# Epoch 37 Batch 500 Loss 0.0481
# Epoch 37 Batch 600 Loss 0.0209
# Epoch 37 Batch 700 Loss 0.0461
# Epoch 37 Batch 800 Loss 0.0376
# Epoch 37 Batch 900 Loss 0.0618
# Epoch 37 Batch 1000 Loss 0.0466
# Epoch 37 Batch 1100 Loss 0.0630
# Epoch 37 Batch 1200 Loss 0.0518
# Epoch 37 Loss 0.0522
# Time taken for 1 epoch 787.6506843566895 sec
#
# Epoch 38 Batch 0 Loss 0.0483
# Epoch 38 Batch 100 Loss 0.0477
# Epoch 38 Batch 200 Loss 0.0392
# Epoch 38 Batch 300 Loss 0.0380
# Epoch 38 Batch 400 Loss 0.0530
# Epoch 38 Batch 500 Loss 0.0473
# Epoch 38 Batch 600 Loss 0.0485
# Epoch 38 Batch 700 Loss 0.0477
# Epoch 38 Batch 800 Loss 0.0359
# Epoch 38 Batch 900 Loss 0.0657
# Epoch 38 Batch 1000 Loss 0.0766
# Epoch 38 Batch 1100 Loss 0.0323
# Epoch 38 Batch 1200 Loss 0.0448
# Epoch 38 Loss 0.0513
# Time taken for 1 epoch 790.4513432979584 sec
#
# Epoch 39 Batch 0 Loss 0.0198
# Epoch 39 Batch 100 Loss 0.0316
# Epoch 39 Batch 200 Loss 0.0296
# Epoch 39 Batch 300 Loss 0.0347
# Epoch 39 Batch 400 Loss 0.0447
# Epoch 39 Batch 500 Loss 0.0198
# Epoch 39 Batch 600 Loss 0.0432
# Epoch 39 Batch 700 Loss 0.0711
# Epoch 39 Batch 800 Loss 0.0530
# Epoch 39 Batch 900 Loss 0.0499
# Epoch 39 Batch 1000 Loss 0.0724
# Epoch 39 Batch 1100 Loss 0.0597
# Epoch 39 Batch 1200 Loss 0.0410
# Epoch 39 Loss 0.0503
# Time taken for 1 epoch 776.1508092880249 sec
#
# Epoch 40 Batch 0 Loss 0.0154
# Epoch 40 Batch 100 Loss 0.0297
# Epoch 40 Batch 200 Loss 0.0546
# Epoch 40 Batch 300 Loss 0.0189
# Epoch 40 Batch 400 Loss 0.0358
# Epoch 40 Batch 500 Loss 0.0387
# Epoch 40 Batch 600 Loss 0.0689
# Epoch 40 Batch 700 Loss 0.0773
# Epoch 40 Batch 800 Loss 0.0353
# Epoch 40 Batch 900 Loss 0.0533
# Epoch 40 Batch 1000 Loss 0.0362
# Epoch 40 Batch 1100 Loss 0.0672
# Epoch 40 Batch 1200 Loss 0.0694
# Epoch 40 Loss 0.0508
# Time taken for 1 epoch 789.6556828022003 sec
#
# Epoch 41 Batch 0 Loss 0.0357
# Epoch 41 Batch 100 Loss 0.0209
# Epoch 41 Batch 200 Loss 0.0434
# Epoch 41 Batch 300 Loss 0.0724
# Epoch 41 Batch 400 Loss 0.0463
# Epoch 41 Batch 500 Loss 0.0437
# Epoch 41 Batch 600 Loss 0.0863
# Epoch 41 Batch 700 Loss 0.0704
# Epoch 41 Batch 800 Loss 0.0504
# Epoch 41 Batch 900 Loss 0.0395
# Epoch 41 Batch 1000 Loss 0.0717
# Epoch 41 Batch 1100 Loss 0.0502
# Epoch 41 Batch 1200 Loss 0.0367
# Epoch 41 Loss 0.0504
# Time taken for 1 epoch 785.2728457450867 sec
#
# Epoch 42 Batch 0 Loss 0.0227
# Epoch 42 Batch 100 Loss 0.0201
# Epoch 42 Batch 200 Loss 0.0788
# Epoch 42 Batch 300 Loss 0.0263
# Epoch 42 Batch 400 Loss 0.0815
# Epoch 42 Batch 500 Loss 0.0334
# Epoch 42 Batch 600 Loss 0.0411
# Epoch 42 Batch 700 Loss 0.0668
# Epoch 42 Batch 800 Loss 0.0582
# Epoch 42 Batch 900 Loss 0.0638
# Epoch 42 Batch 1000 Loss 0.0836
# Epoch 42 Batch 1100 Loss 0.0378
# Epoch 42 Batch 1200 Loss 0.0548
# Epoch 42 Loss 0.0496
# Time taken for 1 epoch 767.6038610935211 sec
#
# Epoch 43 Batch 0 Loss 0.0325
# Epoch 43 Batch 100 Loss 0.0411
# Epoch 43 Batch 200 Loss 0.0339
# Epoch 43 Batch 300 Loss 0.0474
# Epoch 43 Batch 400 Loss 0.0451
# Epoch 43 Batch 500 Loss 0.0562
# Epoch 43 Batch 600 Loss 0.0624
# Epoch 43 Batch 700 Loss 0.0501
# Epoch 43 Batch 800 Loss 0.0573
# Epoch 43 Batch 900 Loss 0.0672
# Epoch 43 Batch 1000 Loss 0.0705
# Epoch 43 Batch 1100 Loss 0.0563
# Epoch 43 Batch 1200 Loss 0.0461
# Epoch 43 Loss 0.0497
# Time taken for 1 epoch 782.670651435852 sec
#
# Epoch 44 Batch 0 Loss 0.0412
# Epoch 44 Batch 100 Loss 0.0316
# Epoch 44 Batch 200 Loss 0.0236
# Epoch 44 Batch 300 Loss 0.0550
# Epoch 44 Batch 400 Loss 0.0369
# Epoch 44 Batch 500 Loss 0.0112
# Epoch 44 Batch 600 Loss 0.0198
# Epoch 44 Batch 700 Loss 0.0363
# Epoch 44 Batch 800 Loss 0.0234
# Epoch 44 Batch 900 Loss 0.0370
# Epoch 44 Batch 1000 Loss 0.0516
# Epoch 44 Batch 1100 Loss 0.0466
# Epoch 44 Batch 1200 Loss 0.0901
# Epoch 44 Loss 0.0487
# Time taken for 1 epoch 781.5695049762726 sec
#
# Epoch 45 Batch 0 Loss 0.0316
# Epoch 45 Batch 100 Loss 0.0265
# Epoch 45 Batch 200 Loss 0.0509
# Epoch 45 Batch 300 Loss 0.0400
# Epoch 45 Batch 400 Loss 0.0234
# Epoch 45 Batch 500 Loss 0.0475
# Epoch 45 Batch 600 Loss 0.0296
# Epoch 45 Batch 700 Loss 0.0457
# Epoch 45 Batch 800 Loss 0.0678
# Epoch 45 Batch 900 Loss 0.0552
# Epoch 45 Batch 1000 Loss 0.0521
# Epoch 45 Batch 1100 Loss 0.0607
# Epoch 45 Batch 1200 Loss 0.0446
# Epoch 45 Loss 0.0491
# Time taken for 1 epoch 763.874835729599 sec
#
# Epoch 46 Batch 0 Loss 0.0311
# Epoch 46 Batch 100 Loss 0.0522
# Epoch 46 Batch 200 Loss 0.0280
# Epoch 46 Batch 300 Loss 0.0514
# Epoch 46 Batch 400 Loss 0.0353
# Epoch 46 Batch 500 Loss 0.0413
# Epoch 46 Batch 600 Loss 0.0556
# Epoch 46 Batch 700 Loss 0.0527
# Epoch 46 Batch 800 Loss 0.0660
# Epoch 46 Batch 900 Loss 0.0503
# Epoch 46 Batch 1000 Loss 0.0714
# Epoch 46 Batch 1100 Loss 0.0364
# Epoch 46 Batch 1200 Loss 0.0688
# Epoch 46 Loss 0.0487
# Time taken for 1 epoch 782.7069554328918 sec
#
# Epoch 47 Batch 0 Loss 0.0408
# Epoch 47 Batch 100 Loss 0.0624
# Epoch 47 Batch 200 Loss 0.0536
# Epoch 47 Batch 300 Loss 0.0474
# Epoch 47 Batch 400 Loss 0.0385
# Epoch 47 Batch 500 Loss 0.0607
# Epoch 47 Batch 600 Loss 0.0383
# Epoch 47 Batch 700 Loss 0.0321
# Epoch 47 Batch 800 Loss 0.0381
# Epoch 47 Batch 900 Loss 0.0464
# Epoch 47 Batch 1000 Loss 0.0375
# Epoch 47 Batch 1100 Loss 0.0199
# Epoch 47 Batch 1200 Loss 0.0797
# Epoch 47 Loss 0.0484
# Time taken for 1 epoch 796.8788714408875 sec
#
# Epoch 48 Batch 0 Loss 0.0352
# Epoch 48 Batch 100 Loss 0.0444
# Epoch 48 Batch 200 Loss 0.0341
# Epoch 48 Batch 300 Loss 0.0615
# Epoch 48 Batch 400 Loss 0.0309
# Epoch 48 Batch 500 Loss 0.0431
# Epoch 48 Batch 600 Loss 0.0529
# Epoch 48 Batch 700 Loss 0.0666
# Epoch 48 Batch 800 Loss 0.0699
# Epoch 48 Batch 900 Loss 0.0624
# Epoch 48 Batch 1000 Loss 0.0450
# Epoch 48 Batch 1100 Loss 0.0547
# Epoch 48 Batch 1200 Loss 0.0717
# Epoch 48 Loss 0.0478
# Time taken for 1 epoch 767.1651945114136 sec
#
# Epoch 49 Batch 0 Loss 0.0415
# Epoch 49 Batch 100 Loss 0.0502
# Epoch 49 Batch 200 Loss 0.0178
# Epoch 49 Batch 300 Loss 0.0221
# Epoch 49 Batch 400 Loss 0.0387
# Epoch 49 Batch 500 Loss 0.0422
# Epoch 49 Batch 600 Loss 0.0582
# Epoch 49 Batch 700 Loss 0.0334
# Epoch 49 Batch 800 Loss 0.0649
# Epoch 49 Batch 900 Loss 0.0296
# Epoch 49 Batch 1000 Loss 0.0630
# Epoch 49 Batch 1100 Loss 0.0683
# Epoch 49 Batch 1200 Loss 0.0671
# Epoch 49 Loss 0.0473
# Time taken for 1 epoch 772.6116273403168 sec
#
# Epoch 50 Batch 0 Loss 0.0272
# Epoch 50 Batch 100 Loss 0.0213
# Epoch 50 Batch 200 Loss 0.0451
# Epoch 50 Batch 300 Loss 0.0169
# Epoch 50 Batch 400 Loss 0.0672
# Epoch 50 Batch 500 Loss 0.0475
# Epoch 50 Batch 600 Loss 0.0607
# Epoch 50 Batch 700 Loss 0.0345
# Epoch 50 Batch 800 Loss 0.0455
# Epoch 50 Batch 900 Loss 0.0627
# Epoch 50 Batch 1000 Loss 0.0378
# Epoch 50 Batch 1100 Loss 0.0478
# Epoch 50 Batch 1200 Loss 0.0345
# Epoch 50 Loss 0.0475
# Time taken for 1 epoch 788.6844477653503 sec
#
# CPU times: user 1d 7h 55min 49s, sys: 4h 6min 5s, total: 1d 12h 1min 54s
# Wall time: 10h 50min 43s

# %% [markdown]
# ### Translate

# %% [markdown]
# - The evaluate function is similar to the training loop, except we don't use teacher forcing here. The input to the decoder at each time step is its previous predictions along with the hidden state and the encoder output.
# - Stop predicting when the model predicts the end token.
# - And store the attention weights for every time step.
# Note: The encoder output is calculated only once for one input.

# %%
def evaluate(sentence):
    attention_plot = np.zeros((max_length_targ, max_length_inp))

    sentence = preprocess_sentence(sentence)

    inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
    inputs = tf.convert_to_tensor(inputs)

    result = ''

    hidden = [tf.zeros((1, units))]
    enc_hidden = encoder(inputs, hidden)

    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

    for t in range(max_length_targ):
        predictions, dec_hidden = decoder(dec_input, dec_hidden)
        
        # storing the attention weights to plot later on
        predicted_id = tf.argmax(predictions[0]).numpy()
        result += targ_lang.index_word[predicted_id] + ' '
        
        if targ_lang.index_word[predicted_id] == '<end>':
            return result, sentence

        # the predicted ID is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)

    return result, sentence

# %%
def translate(sentence):
    result, sentence = evaluate(sentence)
    
    print('Input: %s' % (sentence))
    print('Predicted translation: {}'.format(result))

# %% [markdown]
# ### Restore the latest checkpoint and test

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate('Здесь хорошо.')
# Out:
# Input: <start> здесь хорошо . <end>
# Predicted translation: it's fine here . <end>

# %%
translate('Я делаю работу')
# Out:
# Input: <start> я делаю работу <end>
# Predicted translation: i'm doing the job . <end>

# %%
translate('Он смотрит в ')
# Out:
# Input: <start> он смотрит в <end>
# Predicted translation: he's looking at . <end>

# %%
translate('Она пошла в магазин')
# Out:
# Input: <start> она пошла в магазин <end>
# Predicted translation: she went to the shop . <end>

# %%
translate('Получилось неплохо')
# Out:
# Input: <start> получилось неплохо <end>
# Predicted translation: this isn't bad . <end>
